# %% [markdown]
# # 作業1
# 選擇的資料：Video Game Sales
# ## 1. 你選的這組資料為何重要
# 想知道怎樣的遊戲會大賣，可以拿來作為預購遊戲的參考
# ## 2. 資料從何而來
# 提供者：GregorySmith
# 資料來源：從 http://www.vgchartz.com/ 抓取下來
# ## 3. 蒐集而來的資料型態為何
# 結構化的表格(CSV)
# ## 4. 這組資料想解決的問題如何評估
# 能否正確預測某款遊戲的銷量

# %% [markdown]
# # 作業2
# ## 1. 核心問題為何
# 目的：減少成本（計程車沒載客的空車時間）增加收入，提升每輛車的載客比率（載客時間占所有營運時間的比例。）
# 可能手段：找出載客比率相對低的時段或地點，減少出車；反之在高載客率時段或地點增加出車。看長途載客的回程載客比例，調整長途價格或限制長途距離。
# ## 2. 資料從何而來
# 計程車的載客上下車地點、時間、收費，現有車隊的計費裝置上似乎就有GPS等資訊。
# ## 3. 蒐集而來的資料型態為何
# 結構化的表格
# ## 4. 你要回答的問題，其如何評估
# 找出出車時段與地點與載客比率的關係，看能否正確預測載客比率

# %% [markdown]
# # 作業3

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y, yp):
    mse = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 250.273
# The Mean absolute error is 12.218
